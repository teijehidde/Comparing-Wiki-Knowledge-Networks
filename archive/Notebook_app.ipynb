# %%
# Setup packages 
from collections import Counter
from collections import ChainMap
from dash_bootstrap_components._components.Row import Row
import pandas as pd
from pandas.core.common import flatten
import numpy as np
import networkx as nx
from networkx.algorithms import approximation
from networkx.algorithms.community import greedy_modularity_communities
import networkx.algorithms
import networkx.utils # (algorithms to check out: "approximation", "eccentricity", "diameter", "radius", "periphery", "center", "barycenter", "Community" "degree_centrality", "constraint", "local_constraint", "effective_size") 

# Dash packages needed for building dash app 

import dash
import dash_core_components as dcc
import dash_bootstrap_components as dbc
import dash_html_components as html
import dash_cytoscape as cyto
import dash_table
from dash.dependencies import Input, Output, State
from dash.exceptions import PreventUpdate

# setup layout and paths
path = "/home/teijehidde/Documents/Git Blog and Coding/"
data_file = "data_dump/data_new6.json" 
external_stylesheets = path + 'Comparing Wikipedia Knowledge Networks (Network Analysis Page links)/Code/stylesheet.css' # downloaded from: https://codepen.io/chriddyp/pen/bWLwgP.css. Should appear in credits! 
app = dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])
styles = {
    'pre': {
        'border': 'thin lightgrey solid',
        'overflowX': 'scroll'
    }
}
colors = {
    'background': 'white', # use color coding later. 
    'text': 'gray'
}
list_colours = ['red', 'blue', 'purple','orange','green','olive', 'maroon', 'brown','lime','teal' ]

# %%
# loading data. 
network_data_df = pd.read_json((path + data_file), orient='split')
all_networks = network_data_df.loc[network_data_df['ego'] == True].loc[network_data_df['lang'] == 'en']['title'].values.tolist()

# %%
# setting up classes WikiNode and WikiNetwork. 
class WikiNode:
    def __init__(self, node_title, lang, network_data):

        node_data = network_data.loc[network_data['title'] == node_title].loc[network_data['lang'] == lang]
        
        self.node_title = node_data[['title']].iloc[0,0] # iloc[0,0] needed because there can be two instance of same wikipage in the dataframe: one as centralnode (with langlinks) and one as a normal node of other network (without langlinks).  
        self.node_ID = node_data[['uniqueid']].iloc[0,0]
        self.node_links = node_data[['links']].iloc[0,0]
        self.node_lang = node_data[['lang']].iloc[0,0]
        try: 
            self.node_translation = node_data['langlinks'].values.tolist()[0][0]['*']
        except: 
            self.node_translation = '.'

# %%
class WikiNetwork(WikiNode):
   
    def __init__(self, node_title, lang, threshold = 0):
        
        WikiNode.__init__(self, node_title, lang, network_data = network_data_df)
        self.threshold = threshold
        self.network_nodes = {}
        self.network_links = [node_title]
        self.network_edges = [] 
        self.network_status = []
        
        # Go through node_links of the central node (node_title) to build network.
        for link in self.node_links + [self.node_title]:
            try: 
                Node2 = WikiNode(link, lang, network_data = network_data_df) # NB: the links are not always in the same language as the network. It throws an error as result. - for now it just skips. 
                purged_links = [x for x in Node2.node_links if x in self.node_links]
                purged_edges = []
                for purged_link in purged_links:
                    purged_edges.append((link,purged_link))  
                self.network_nodes[Node2.node_ID] = Node2
                self.network_links = self.network_links + purged_links
                self.network_edges = self.network_edges + purged_edges
            except: 
                pass
        self.links_count = Counter(self.network_links)

    def getNodes(self, type="cytoscape"):
        selected_nodes = [k for k,v in self.links_count.items() if float(v) >= self.threshold]
        
        if type == 'networkx':
            return [(i, {"name": i}) for i in selected_nodes]
        if type == 'cytoscape':
            return [{'data': {'id': i, "label": i}} for i in selected_nodes]

    def getEdges(self,type="cytoscape"):  
        selected_nodes = [k for k,v in self.links_count.items() if float(v) >= self.threshold]
        edges_network = [(a,b) for a,b in self.network_edges if a in selected_nodes and b in selected_nodes]
        
        if type == 'networkx':
            return edges_network
        if type == 'cytoscape':
            return [{'data': {'source': a, "target": b}} for a,b in edges_network]

    def getTranslations(self):
        selected_nodes = [k for k,v in self.links_count.items() if float(v) >= self.threshold]
        translation_list = [(self.network_nodes[i].node_title, self.network_nodes[i].node_translation) for i in self.network_nodes if self.network_nodes[i].node_title in selected_nodes]
        
        translation_nodes = {} 
        for node in selected_nodes:
            try: 
                translation_nodes[node] = [t[1] for t in translation_list if t[0] == node][0]
            except: 
                translation_nodes[node] = '...'

        return pd.DataFrame({'translation':pd.Series(translation_nodes)})

    def getStatsNodes(self):
        G = nx.Graph()
        G.add_edges_from(self.getEdges(type = 'networkx'))
        centrality_nodes = networkx.algorithms.centrality.eigenvector_centrality(G)
        # eccentricity_nodes = networkx.algorithms.distance_measures.eccentricity(G)
        df = pd.DataFrame({'network_centrality':pd.Series(centrality_nodes)}) #  'eccentricity':pd.Series(eccentricity_nodes) 

        val_max = max(df['network_centrality'])
        val_min = min(df['network_centrality'])
        df[['centrality_normalized']] = df[['network_centrality']].apply(lambda x: (x - val_min) / (val_max - val_min), result_type = 'expand')
        df[['centrality_rounded']] = df[['network_centrality']].apply(lambda x: round(x, 2))

        return df

    def getStatsCommunities(self):
        G = nx.Graph()
        G.add_edges_from(self.getEdges(type = 'networkx'))
        communities = greedy_modularity_communities(G)
        dict_communities = {key:value for value in range(len(communities)) for key in communities[value] }

        community_centrality_nodes = {}
        for community in communities:
            selected_edges = [(a,b) for a,b in G.edges if a in community if b in community]
            G_community = nx.Graph()
            G_community.add_edges_from(selected_edges)
            community_centrality_nodes.update(networkx.algorithms.centrality.degree_centrality(G))
            
        return pd.DataFrame({'community':pd.Series(dict_communities), 'community_centrality': pd.Series(community_centrality_nodes)}) 

    def getStatsNetwork(self):
        G = nx.Graph()
        G.add_edges_from(self.getEdges(type = 'networkx'))
        return networkx.algorithms.approximation.clustering_coefficient.average_clustering(G, trials=1000, seed=10)

# %%
wiki_page = WikiNetwork('ワクチン', 'ja')

# %%
wiki_page.getStatsNetwork()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-199-860ed58cc386> in <module>
# ----> 1 wiki_page.getStatsNetwork()
#
# <ipython-input-197-2f9f9677a1eb> in getStatsNetwork(self)
#      86     def getStatsNetwork(self):
#      87         G = nx.Graph().add_edges_from(self.getEdges(type = 'networkx'))
# ---> 88         return networkx.algorithms.approximation.clustering_coefficient.average_clustering(G, trials=1000, seed=10)
#
# <decorator-gen-875> in average_clustering(G, trials, seed)
#
# ~/.local/lib/python3.8/site-packages/networkx/utils/decorators.py in _random_state(func, *args, **kwargs)
#     467         new_args = list(args)
#     468         new_args[random_state_index] = random_state
# --> 469         return func(*new_args, **kwargs)
#     470
#     471     return _random_state
#
# <decorator-gen-874> in average_clustering(G, trials, seed)
#
# ~/.local/lib/python3.8/site-packages/networkx/utils/decorators.py in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      59         graph = args[0]
#      60         terms = {
# ---> 61             "directed": graph.is_directed(),
#      62             "undirected": not graph.is_directed(),
#      63             "multigraph": graph.is_multigraph(),
#
# AttributeError: 'NoneType' object has no attribute 'is_directed'

# %%
node_title = 'ワクチン'
lang = 'ja'

nodes = wiki_page.getNodes(type='cytoscape')
edges = wiki_page.getEdges(type='cytoscape')
nodes_translations = wiki_page.getTranslations()
stats_nodes = wiki_page.getStatsNodes()
stats_communities = wiki_page.getStatsCommunities()

# pd_nodes = pd.DataFrame([{'page_ID': v.node_ID, 'title': v.node_title} for v in wiki_page.network_nodes.values()]).set_index('title', drop = False)
pd_nodes = pd.concat([nodes_translations, stats_nodes, stats_communities], axis = 1).reset_index() # pd_nodes,
pd_nodes = pd_nodes.rename(columns={'index': 'title'})

# {'node_title': node_title, 'lang': lang, 'nodes_network': nodes, 'edges_network': edges, 'nodes_stats': pd_nodes.to_dict('records')}

# %%
pd_nodes
# Out:
#                           title translation  network_centrality  \
# 0                         1798年        1798            0.000992
# 1                         1971年        1971            0.003558
# 2                         2019年        2019            0.001732
# 3                      ATCコード A  ATC code A            0.098432
# 4                      ATCコード D  ATC code D            0.098432
# ..                          ...         ...                 ...
# 337              RVSV-ZEBOVワクチン         NaN            0.000904
# 338                    挿入 (遺伝学)         NaN            0.000918
# 339                    MMRVワクチン         NaN            0.000921
# 340  2017年コンゴ民主共和国 エボラウイルス感染症発生         NaN            0.000886
# 341                      異種ワクチン         NaN            0.000886
#
#      centrality_normalized  centrality_rounded  community  \
# 0                 0.000991                 0.0          0
# 1                 0.025093                 0.0          0
# 2                 0.007941                 0.0          0
# 3                 0.916228                 0.1          1
# 4                 0.916228                 0.1          1
# ..                     ...                 ...        ...
# 337               0.000167                 0.0          0
# 338               0.000298                 0.0          0
# 339               0.000323                 0.0          0
# 340               0.000000                 0.0          0
# 341               0.000000                 0.0          0
#
#      community_centrality
# 0                0.011730
# 1                0.049853
# 2                0.043988
# 3                0.460411
# 4                0.460411
# ..                    ...
# 337              0.005865
# 338              0.005865
# 339              0.005865
# 340              0.002933
# 341              0.002933
#
# [342 rows x 7 columns]

# %%
selected_nodes = [k for k,v in wiki_page.links_count.items() if float(v) >= wiki_page.threshold]
[(wiki_page.network_nodes[i].node_title, wiki_page.network_nodes[i].node_translation) for i in wiki_page.network_nodes if wiki_page.network_nodes[i].node_title in selected_nodes]
# Out:
# ['1798',
#  '1971',
#  '2019',
#  'ATC code A',
#  'ATC code D',
#  'ATC code D09',
#  'Hepatitis A vaccine',
#  'BCG vaccine',
#  '.',
#  '.',
#  'Hepatitis B vaccine',
#  '.',
#  'COVID-19 vaccine',
#  'Hepatitis C',
#  '.',
#  'DNA vaccine',
#  '.',
#  'Hib vaccine',
#  'International Standard Book Number',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'RNA vaccine',
#  'T-cell receptor',
#  'WHO Model List of Essential Medicines',
#  'Cancer vaccine',
#  '.',
#  'Immunologic adjuvant',
#  'Atopic dermatitis',
#  'Anabolic steroid',
#  'Centers for Disease Control and Prevention',
#  'American English',
#  '.',
#  'Angiotensin II receptor blocker',
#  'ACE inhibitor',
#  'Antivirus software',
#  'International Certificate of Vaccination or Prophylaxis',
#  'United Kingdom',
#  'British English',
#  'Influenza',
#  'Influenza vaccine',
#  '.',
#  'Virus',
#  'Viral vector vaccine',
#  '.',
#  'Edward Jenner',
#  'Ebola',
#  '.',
#  '.',
#  '.',
#  'Otto Gottlieb Mohnike',
#  'Calcium channel blocker',
#  'Guillain–Barré syndrome',
#  'GlaxoSmithKline',
#  'Coccidioidomycosis',
#  '.',
#  'Cohort study',
#  'Cholera vaccine',
#  'Democratic Republic of the Congo',
#  'Psychedelia',
#  'Cytokine',
#  'Sanofi',
#  '.',
#  'Subunit vaccine',
#  'Diphtheria',
#  'Switzerland',
#  'Statin',
#  'Nootropic',
#  'Protein',
#  'Daniel Kahneman',
#  'Tick-borne encephalitis vaccine',
#  'Thiomersal',
#  'DNA',
#  'Digital object identifier',
#  'Deliriant',
#  'Denka (company)',
#  '.',
#  'Toxoid',
#  'German language',
#  'Novartis',
#  'Pandemic',
#  'H2 antagonist',
#  'HPV vaccine',
#  'Bisphosphonate',
#  'Vitamin',
#  'Pfizer',
#  'Fibrate',
#  'Booster dose',
#  'Plasmid',
#  'Proton-pump inhibitor',
#  'Formalin',
#  '.',
#  'Polio vaccine',
#  'Mineral (nutrient)',
#  '.',
#  '.',
#  'Latin',
#  'La Stampa',
#  'Rickettsia',
#  'Luc Montagnier',
#  'Louis Pasteur',
#  'Renin–angiotensin system',
#  'Rotavirus vaccine',
#  '.',
#  'Vaccine hesitancy',
#  'DPT vaccine',
#  'Inactivated vaccine',
#  'World',
#  'World Health Organization',
#  '.',
#  'Preventive healthcare',
#  'Vaccination',
#  '.',
#  '.',
#  'Beta blocker',
#  'Metabolism',
#  'Decongestant',
#  '.',
#  '.',
#  'Immunogenicity',
#  'Immune response',
#  'Immunosuppressive drug',
#  'Immune system',
#  '.',
#  'Lupus',
#  'General anaesthesia',
#  'Endocrine system',
#  'Coagulation',
#  'Diuretic',
#  'Antiemetic',
#  'Antacid',
#  'Vaccine adverse event',
#  'Corticosteroid',
#  '.',
#  'Medication',
#  'Ministry of Health, Labour and Welfare',
#  '.',
#  'Mouth',
#  'Mouth ulcer',
#  'Synthetic vaccine',
#  'Respiratory system',
#  '.',
#  'National Institute of Infectious Diseases (Japan)',
#  'United Nations',
#  'International Phonetic Alphabet',
#  '.',
#  'Microbiological culture',
#  'Multiple sclerosis',
#  '.',
#  '.',
#  'Smallpox',
#  '.',
#  'Shingles',
#  'Hallucinogen',
#  '.',
#  'Live attenuated influenza vaccine',
#  'Cardiac glycoside',
#  '.',
#  'Microorganism',
#  'Acute disseminated encephalomyelitis',
#  'Polio',
#  'Sex hormone',
#  'Cancer',
#  'Infection',
#  'Infectious disease',
#  'Sense',
#  'Depressant',
#  'Antidepressant',
#  '.',
#  'Anticonvulsant',
#  'Antiviral drug',
#  "Pharmacological treatment of Parkinson's disease",
#  'Antihistamine',
#  'Anxiolytic',
#  'Antiarrhythmic agent',
#  'Antibody',
#  'Anticoagulant',
#  '.',
#  'Antigen',
#  'Antiprotozoal',
#  'Antiparasitic',
#  '.',
#  'Antitoxin',
#  'Anti-inflammatory',
#  'Antibiotic',
#  'Antithyroid agent',
#  'Antifungal',
#  'Antipsychotic',
#  'Bactericide',
#  'Antiplatelet drug',
#  'Ziehl–Neelsen stain',
#  'MMR vaccine',
#  'COVID-19',
#  'Japanese people',
#  'Japanese encephalitis vaccine',
#  'Japanese language',
#  '.',
#  'North Korea',
#  '.',
#  'Antidiarrhoeal',
#  'Takeda Pharmaceutical Company',
#  'Toxin',
#  'Mood stabilizer',
#  'Bronchodilator',
#  'Chickenpox',
#  'Varicella vaccine',
#  '.',
#  'Injection (medicine)',
#  '.',
#  'Attention deficit hyperactivity disorder',
#  'Mumps',
#  'Mumps vaccine',
#  'Human digestive system',
#  'Humoral immunity',
#  'Hydrocolloid dressing',
#  'Laxative',
#  'Inflammatory myopathy',
#  'Bacillus anthracis',
#  'Cowpox',
#  'Rabies vaccine',
#  'Antianginal',
#  'Attenuated vaccine',
#  'Sankei Shimbun',
#  'Thyroid hormones',
#  'Disease-modifying antirheumatic drug',
#  'Pathogen',
#  'Whooping cough',
#  'Pertussis vaccine',
#  'Skin',
#  '.',
#  'Ophthalmology',
#  'Hypnotic',
#  'Tetanus',
#  'Nerve',
#  'Neurotoxin',
#  'Smallpox vaccine',
#  'Daiichi Sankyo',
#  'Muscle relaxant',
#  'Muscle',
#  'Intramuscular injection',
#  'Stimulant',
#  'Glucocorticoid',
#  'Cell-mediated immunity',
#  'Bacteria',
#  'Recombinant DNA',
#  'Diabetes medication',
#  'Conjugate vaccine',
#  'Tuberculosis',
#  'Emergency Use Authorization',
#  'Otorhinolaryngology',
#  'Pneumococcal vaccine',
#  'Lipid-lowering agent',
#  'Brain',
#  'Typhoid vaccine',
#  'Autoimmune disease',
#  'Autonomy (disambiguation)',
#  'English language',
#  '.',
#  'Pharmacology',
#  'Platelet',
#  'Thrombolytic drug',
#  'Blood',
#  'Vasodilation',
#  'Anatomical Therapeutic Chemical Classification System',
#  'Antidote',
#  'Dissociative',
#  'Kodansha',
#  'Military',
#  'Contrast agent',
#  'Gene',
#  'Gene expression',
#  '.',
#  'Mineralocorticoid',
#  'Cold medicine',
#  'Analgesic',
#  'Sedative',
#  'Joint',
#  'Rheumatoid arthritis',
#  'Herd immunity',
#  'Anesthetic#Intravenous agents .28non-opioid.29',
#  'Nonsteroidal anti-inflammatory drug',
#  'Rubella',
#  'Rubella vaccine',
#  'Anthelmintic',
#  'Bone',
#  'Meningococcal vaccine',
#  'Antihypertensive drug',
#  'Measles',
#  'Measles vaccine',
#  '.',
#  '.',
#  'Yellow fever vaccine',
#  'Nose',
#  'Entstof']

# %%
wiki_page.network_nodes
# Out:
# {'1718': <__main__.WikiNode at 0x7fe55eec89d0>,
#  '1796': <__main__.WikiNode at 0x7fe55e100730>,
#  '1879': <__main__.WikiNode at 0x7fe55e100df0>,
#  '1881': <__main__.WikiNode at 0x7fe55e100130>,
#  '1884': <__main__.WikiNode at 0x7fe55e100250>,
#  '1885': <__main__.WikiNode at 0x7fe55e100940>,
#  '1890': <__main__.WikiNode at 0x7fe55e100790>,
#  '1897': <__main__.WikiNode at 0x7fe55e100850>,
#  '1926': <__main__.WikiNode at 0x7fe55e100490>,
#  '1927': <__main__.WikiNode at 0x7fe55e1004f0>,
#  '1937': <__main__.WikiNode at 0x7fe55e1007f0>,
#  '1945': <__main__.WikiNode at 0x7fe55e100a60>,
#  '1952': <__main__.WikiNode at 0x7fe55e100bb0>,
#  '1954': <__main__.WikiNode at 0x7fe55e100e20>,
#  '1962': <__main__.WikiNode at 0x7fe55e100f40>,
#  '1964': <__main__.WikiNode at 0x7fe55e100820>,
#  '1967': <__main__.WikiNode at 0x7fe55e1009d0>,
#  '1970': <__main__.WikiNode at 0x7fe55e100b50>,
#  '1974': <__main__.WikiNode at 0x7fe55e100c70>,
#  '1977': <__main__.WikiNode at 0x7fe55e14fa60>,
#  '1978': <__main__.WikiNode at 0x7fe55e14fdf0>,
#  '1981': <__main__.WikiNode at 0x7fe55e14f970>,
#  '1985': <__main__.WikiNode at 0x7fe55e14f310>,
#  '1992': <__main__.WikiNode at 0x7fe55e14f4c0>,
#  '1998': <__main__.WikiNode at 0x7fe55e14ffa0>,
#  '2005': <__main__.WikiNode at 0x7fe55e14f430>,
#  '2009': <__main__.WikiNode at 0x7fe55e1127f0>,
#  '2015': <__main__.WikiNode at 0x7fe55e112700>,
#  '2020': <__main__.WikiNode at 0x7fe55e112760>,
#  'ADN': <__main__.WikiNode at 0x7fe55e1125b0>,
#  'ARN': <__main__.WikiNode at 0x7fe55e112970>,
#  'Administración de Medicamentos y Alimentos': <__main__.WikiNode at 0x7fe55e112250>,
#  'Afganistán': <__main__.WikiNode at 0x7fe55e112c40>,
#  'Agencia Europea de Medicamentos': <__main__.WikiNode at 0x7fe55e112d60>,
#  'Air France': <__main__.WikiNode at 0x7fe55e112af0>,
#  'Andrew Wakefield': <__main__.WikiNode at 0x7fe55e1128e0>,
#  'Anticuerpo': <__main__.WikiNode at 0x7fe55e1129d0>,
#  'Asociación Europea de Libre Comercio': <__main__.WikiNode at 0x7fe55e112f10>,
#  'BNT162b2': <__main__.WikiNode at 0x7fe55e112be0>,
#  'Bacilo de Pfeiffer': <__main__.WikiNode at 0x7fe55e112e80>,
#  'Bacteria': <__main__.WikiNode at 0x7fe55e112b20>,
#  'Bibliothèque nationale de France': <__main__.WikiNode at 0x7fe55e112a30>,
#  'Biotecnología': <__main__.WikiNode at 0x7fe55e112430>,
#  'COVID-19': <__main__.WikiNode at 0x7fe55e112f40>,
#  'Calendario de vacunación': <__main__.WikiNode at 0x7fe55e112df0>,
#  'Cambridge University Press': <__main__.WikiNode at 0x7fe55e112ee0>,
#  'Carbunco': <__main__.WikiNode at 0x7fe55e112ca0>,
#  'Control de autoridades': <__main__.WikiNode at 0x7fe55e112310>,
#  'Controversia de las vacunas': <__main__.WikiNode at 0x7fe55e112ac0>,
#  'Controversia del tiomersal': <__main__.WikiNode at 0x7fe55e112850>,
#  'Cáncer de cérvix': <__main__.WikiNode at 0x7fe55e112d30>,
#  'Código ATC': <__main__.WikiNode at 0x7fe55e112fa0>,
#  'Cólera': <__main__.WikiNode at 0x7fe55e1120d0>,
#  'Cólera aviar': <__main__.WikiNode at 0x7fe55e117a60>,
#  'Diarrea crónica intestinal grave': <__main__.WikiNode at 0x7fe55e117760>,
#  'Difteria': <__main__.WikiNode at 0x7fe55e117850>,
#  'Digital object identifier': <__main__.WikiNode at 0x7fe55e117790>,
#  'Edward Jenner': <__main__.WikiNode at 0x7fe55e117b80>,
#  'Encefalitis japonesa': <__main__.WikiNode at 0x7fe55e1178e0>,
#  'Enciclopedia Británica': <__main__.WikiNode at 0x7fe55e117b20>,
#  'Enfermedad': <__main__.WikiNode at 0x7fe55e117f70>,
#  'Enfermedad de Lyme': <__main__.WikiNode at 0x7fe55e117f10>,
#  'Experimentación con animales': <__main__.WikiNode at 0x7fe55e117eb0>,
#  'Fiebre amarilla': <__main__.WikiNode at 0x7fe55e117d60>,
#  'Fiebre tifoidea': <__main__.WikiNode at 0x7fe55e117d90>,
#  'Gripe': <__main__.WikiNode at 0x7fe55e117c10>,
#  'Gripe A (H1N1)': <__main__.WikiNode at 0x7fe55e117fa0>,
#  'Guerra hispano-estadounidense': <__main__.WikiNode at 0x7fe55e117fd0>,
#  'Haemophilus influenzae': <__main__.WikiNode at 0x7fe55f1fe250>,
#  'Hepatitis A': <__main__.WikiNode at 0x7fe59df99a30>,
#  'Hepatitis B': <__main__.WikiNode at 0x7fe59df995b0>,
#  'Hepatitis C': <__main__.WikiNode at 0x7fe55e117d00>,
#  'Herpes zóster': <__main__.WikiNode at 0x7fe55e117580>,
#  'ISBN': <__main__.WikiNode at 0x7fe55e117bb0>,
#  'Inglaterra': <__main__.WikiNode at 0x7fe55e117ca0>,
#  'Inmunología': <__main__.WikiNode at 0x7fe55e117700>,
#  'Inoculación': <__main__.WikiNode at 0x7fe55ee7b820>,
#  'Integrated Authority File': <__main__.WikiNode at 0x7fe55e1177f0>,
#  'James Gillray': <__main__.WikiNode at 0x7fe55e117d30>,
#  'Jonas Salk': <__main__.WikiNode at 0x7fe55ee7b8e0>,
#  'Lactobacillus': <__main__.WikiNode at 0x7fe55ee7b250>,
#  'Lactococcus': <__main__.WikiNode at 0x7fe55ee7b910>,
#  'Library of Congress Control Number': <__main__.WikiNode at 0x7fe55e109880>,
#  'Louis Pasteur': <__main__.WikiNode at 0x7fe55e1098b0>,
#  'M. tuberculosis': <__main__.WikiNode at 0x7fe55e109970>,
#  'Malaria': <__main__.WikiNode at 0x7fe55e109a00>,
#  'Mary Montagu': <__main__.WikiNode at 0x7fe55e109a90>,
#  'Medical Subject Headings': <__main__.WikiNode at 0x7fe55e109b50>,
#  'Medicina preventiva': <__main__.WikiNode at 0x7fe55e109be0>,
#  'Meningitis': <__main__.WikiNode at 0x7fe55e109c70>,
#  'National Diet Library': <__main__.WikiNode at 0x7fe55e109d00>,
#  'Neisseria meningitidis': <__main__.WikiNode at 0x7fe55e109dc0>,
#  'Neumonía': <__main__.WikiNode at 0x7fe55e109df0>,
#  'Nigeria': <__main__.WikiNode at 0x7fe55e109e80>,
#  'Organización Mundial de la Salud': <__main__.WikiNode at 0x7fe55e109f10>,
#  'Pakistán': <__main__.WikiNode at 0x7fe55e109fa0>,
#  'Pandemia de COVID-19': <__main__.WikiNode at 0x7fe55e109a60>,
#  'Paperas': <__main__.WikiNode at 0x7fe55e109b20>,
#  'Parotiditis': <__main__.WikiNode at 0x7fe55e109cd0>,
#  'París': <__main__.WikiNode at 0x7fe55e109e50>,
#  'Peste': <__main__.WikiNode at 0x7fe55e1099a0>,
#  'Poliomielitis': <__main__.WikiNode at 0x7fe55e109250>,
#  'Polisacárido': <__main__.WikiNode at 0x7fe55e109940>,
#  'Primates': <__main__.WikiNode at 0x7fe55e109bb0>,
#  'Protocolo de investigación': <__main__.WikiNode at 0x7fe55e109d60>,
#  'PubMed Identifier': <__main__.WikiNode at 0x7fe55e107550>,
#  'Rabia': <__main__.WikiNode at 0x7fe55e1075e0>,
#  'Real Expedición Filantrópica de la Vacuna': <__main__.WikiNode at 0x7fe55e107670>,
#  'Retractación de artículos científicos': <__main__.WikiNode at 0x7fe55e107700>,
#  'Rubéola': <__main__.WikiNode at 0x7fe55e107790>,
#  'Salmonella typhi': <__main__.WikiNode at 0x7fe55e107820>,
#  'Sarampión': <__main__.WikiNode at 0x7fe55e1078b0>,
#  'Sida': <__main__.WikiNode at 0x7fe55e107940>,
#  'Siglo XIX': <__main__.WikiNode at 0x7fe55e1079d0>,
#  'Siglo XVIII': <__main__.WikiNode at 0x7fe55e107a60>,
#  'Siglo XX': <__main__.WikiNode at 0x7fe55e107af0>,
#  'Siglo XXI': <__main__.WikiNode at 0x7fe55e107b80>,
#  'Sistema de inmunidad adquirida': <__main__.WikiNode at 0x7fe55e107c10>,
#  'Sistema inmunitario': <__main__.WikiNode at 0x7fe55e107ca0>,
#  'Sistema inmunológico': <__main__.WikiNode at 0x7fe55e107d30>,
#  'Streptococcus pneumoniae': <__main__.WikiNode at 0x7fe55e107dc0>,
#  'Sustancia placebo': <__main__.WikiNode at 0x7fe55e107e50>,
#  'Thiomersal': <__main__.WikiNode at 0x7fe55e107ee0>,
#  'Tifus': <__main__.WikiNode at 0x7fe55e107f70>,
#  'Tos ferina': <__main__.WikiNode at 0x7fe55e107fd0>,
#  'Toxina': <__main__.WikiNode at 0x7fe55e107ac0>,
#  'Tuberculosis': <__main__.WikiNode at 0x7fe55e107c70>,
#  'Tétanos': <__main__.WikiNode at 0x7fe55e107e20>,
#  'Ultracongelador': <__main__.WikiNode at 0x7fe55e1079a0>,
#  'VIH': <__main__.WikiNode at 0x7fe55e107250>,
#  'VII Distrito de París': <__main__.WikiNode at 0x7fe55e107910>,
#  'Vacuna contra el VPH': <__main__.WikiNode at 0x7fe55e107b50>,
#  'Vacuna contra el virus del papiloma humano': <__main__.WikiNode at 0x7fe55e107d00>,
#  'Vacuna contra la influenza': <__main__.WikiNode at 0x7fe55e113550>,
#  'Vacuna contra la poliomielitis': <__main__.WikiNode at 0x7fe55e1135e0>,
#  'Vacuna de ADN': <__main__.WikiNode at 0x7fe55e113670>,
#  'Vacuna de ARN': <__main__.WikiNode at 0x7fe55e113700>,
#  'Vacuna de Pfizer-BioNTech para la COVID-19': <__main__.WikiNode at 0x7fe55e113790>,
#  'Varicela': <__main__.WikiNode at 0x7fe55e113820>,
#  'Viruela': <__main__.WikiNode at 0x7fe55e1138b0>,
#  'Viruela bovina': <__main__.WikiNode at 0x7fe55e113940>,
#  'Virus': <__main__.WikiNode at 0x7fe55e1139d0>,
#  'Virus del papiloma humano': <__main__.WikiNode at 0x7fe55e113a60>,
#  'Virus vaccinia': <__main__.WikiNode at 0x7fe55e113af0>,
#  'Wayback Machine': <__main__.WikiNode at 0x7fe55e113b80>,
#  'Wikidata': <__main__.WikiNode at 0x7fe55e113c10>,
#  'Wikimedia Commons': <__main__.WikiNode at 0x7fe55e113ca0>,
#  'Wikiquote': <__main__.WikiNode at 0x7fe55e113d30>,
#  'Ántrax (forunculosis)': <__main__.WikiNode at 0x7fe55e113dc0>,
#  'Ébola': <__main__.WikiNode at 0x7fe55e113e50>,
#  'Vacuna': <__main__.WikiNode at 0x7fe55e113ee0>}

# %%
nodes = wiki_page.getNodes(type='cytoscape')
edges = wiki_page.getEdges(type='cytoscape')
stats_nodes = wiki_page.getStatsNodes()
stats_communities = wiki_page.getStatsCommunities()
pd_nodes = pd.concat([stats_nodes, stats_communities], axis = 1).reset_index()
pd_nodes = pd_nodes.rename(columns={'index': 'title'})

stats_nodes = {'node_title': 'لقاح', 'lang': 'ar', 'nodes_network': nodes, 'edges_network': edges, 'nodes_stats': pd_nodes.to_dict('records')}

# %%
pd_nodes
# Out:
#                                title  network_centrality  \
# 0                           Ad5-nCOV            0.029839
# 1                        Ad26.COV2.S            0.028962
# 2                             BBV152            0.029839
# 3                      إبيفاك كورونا            0.030260
# 4                       تجربة سريرية            0.049902
# ..                               ...                 ...
# 331                    Betz Halloran            0.001080
# 332               Clin. Infect. Dis.            0.001080
# 333                      أنثى البقرة            0.001080
# 334  القاموس الجهنمي، الطبعة السادسة            0.001080
# 335                 اللقاحات الموهنة            0.001080
#
#      centrality_normalized  centrality_rounded  community  \
# 0                 0.220337                0.03          1
# 1                 0.213615                0.03          1
# 2                 0.220337                0.03          1
# 3                 0.223556                0.03          1
# 4                 0.374040                0.05          1
# ..                     ...                 ...        ...
# 331               0.000000                0.00          0
# 332               0.000000                0.00          0
# 333               0.000000                0.00          0
# 334               0.000000                0.00          0
# 335               0.000000                0.00          0
#
#      community_centrality
# 0                0.247761
# 1                0.238806
# 2                0.247761
# 3                0.250746
# 4                0.346269
# ..                    ...
# 331              0.002985
# 332              0.002985
# 333              0.002985
# 334              0.002985
# 335              0.002985
#
# [336 rows x 6 columns]

# %%
pd.DataFrame.from_dict(stats_nodes['nodes_stats'])
# Out:
#        page_ID                      title  network_centrality  \
# 0    ar8338317                Ad26.COV2.S            0.028962
# 1    ar8030088                   Ad5-nCOV            0.029839
# 2    ar8030084                     BBV152            0.029839
# 3    ar2588132                Open access            0.001333
# 4    ar6874832  أبحاث فيروس الهربس البسيط            0.028765
# ..         ...                        ...                 ...
# 331        NaN                        NaN            0.001080
# 332        NaN                        NaN            0.001080
# 333        NaN                        NaN            0.001080
# 334        NaN                        NaN            0.001080
# 335        NaN                        NaN            0.001080
#
#      centrality_normalized  centrality_rounded  community  \
# 0                 0.213615                0.03          1
# 1                 0.220337                0.03          1
# 2                 0.220337                0.03          1
# 3                 0.001941                0.00          1
# 4                 0.212103                0.03          1
# ..                     ...                 ...        ...
# 331               0.000000                0.00          0
# 332               0.000000                0.00          0
# 333               0.000000                0.00          0
# 334               0.000000                0.00          0
# 335               0.000000                0.00          0
#
#      community_centrality
# 0                0.238806
# 1                0.247761
# 2                0.247761
# 3                0.005970
# 4                0.226866
# ..                    ...
# 331              0.002985
# 332              0.002985
# 333              0.002985
# 334              0.002985
# 335              0.002985
#
# [336 rows x 7 columns]

# %%
int(stats_nodes.loc['وبائيات']['community'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-2f681eab8397> in <module>
# ----> 1 int(stats_nodes.loc['وبائيات']['community'])
#
# AttributeError: 'dict' object has no attribute 'loc'

# %%
nodes = wiki_page.getNodes(type='cytoscape')
edges = wiki_page.getEdges(type='cytoscape')
stats_nodes = wiki_page.getStatsNodes()
stats_communities = wiki_page.getStatsCommunities()

pd_nodes = pd.DataFrame([{'page_ID': v.node_ID, 'title': v.node_title} for v in wiki_page.network_nodes.values()]).set_index('title', drop = False)
pd_nodes = pd.concat([pd_nodes, stats_nodes, stats_communities], axis = 1)

data = {'nodes_network': nodes, 'edges_network': edges, 'nodes_stats': pd_nodes.to_dict('records')}

# %%
stats_nodes = pd.DataFrame.from_dict(data['nodes_stats']) 
stats_nodes = stats_nodes.set_index('title', drop = False)

# %%
stats_nodes
# Out:
#                                                        page_ID  \
# title
# 2009 swine flu pandemic vaccine                     en23224587
# 2017 Democratic Republic of the Congo Ebola vir...  en54039081
# ABC News (Australia)                                 en4797328
# ACE inhibitor                                           en2767
# AIDS                                                en36056314
# ...                                                        ...
# Zika virus vaccine                                  en53907564
# Zoster vaccine                                       en8125462
# Vaccine                                                en32653
# NaN                                                        NaN
# NaN                                                        NaN
#
#                                                                                                 title  \
# title
# 2009 swine flu pandemic vaccine                                       2009 swine flu pandemic vaccine
# 2017 Democratic Republic of the Congo Ebola vir...  2017 Democratic Republic of the Congo Ebola vi...
# ABC News (Australia)                                                             ABC News (Australia)
# ACE inhibitor                                                                           ACE inhibitor
# AIDS                                                                                             AIDS
# ...                                                                                               ...
# Zika virus vaccine                                                                 Zika virus vaccine
# Zoster vaccine                                                                         Zoster vaccine
# Vaccine                                                                                       Vaccine
# NaN                                                                                               NaN
# NaN                                                                                               NaN
#
#                                                     network_centrality  \
# title
# 2009 swine flu pandemic vaccine                               0.316393
# 2017 Democratic Republic of the Congo Ebola vir...            0.016393
# ABC News (Australia)                                          0.004918
# ACE inhibitor                                                 0.283607
# AIDS                                                          0.029508
# ...                                                                ...
# Zika virus vaccine                                            0.157377
# Zoster vaccine                                                0.162295
# Vaccine                                                       1.000000
# NaN                                                           0.001639
# NaN                                                           0.001639
#
#                                                     centrality_normalized  \
# title
# 2009 swine flu pandemic vaccine                                  0.315271
# 2017 Democratic Republic of the Congo Ebola vir...               0.014778
# ABC News (Australia)                                             0.003284
# ACE inhibitor                                                    0.282430
# AIDS                                                             0.027915
# ...                                                                   ...
# Zika virus vaccine                                               0.155993
# Zoster vaccine                                                   0.160920
# Vaccine                                                          1.000000
# NaN                                                              0.000000
# NaN                                                              0.000000
#
#                                                     centrality_rounded  \
# title
# 2009 swine flu pandemic vaccine                                   0.32
# 2017 Democratic Republic of the Congo Ebola vir...                0.02
# ABC News (Australia)                                              0.00
# ACE inhibitor                                                     0.28
# AIDS                                                              0.03
# ...                                                                ...
# Zika virus vaccine                                                0.16
# Zoster vaccine                                                    0.16
# Vaccine                                                           1.00
# NaN                                                               0.00
# NaN                                                               0.00
#
#                                                     community  \
# title
# 2009 swine flu pandemic vaccine                             0
# 2017 Democratic Republic of the Congo Ebola vir...          0
# ABC News (Australia)                                        0
# ACE inhibitor                                               1
# AIDS                                                        0
# ...                                                       ...
# Zika virus vaccine                                          0
# Zoster vaccine                                              0
# Vaccine                                                     0
# NaN                                                         0
# NaN                                                         0
#
#                                                     community_centrality
# title
# 2009 swine flu pandemic vaccine                                 0.316393
# 2017 Democratic Republic of the Congo Ebola vir...              0.016393
# ABC News (Australia)                                            0.004918
# ACE inhibitor                                                   0.283607
# AIDS                                                            0.029508
# ...                                                                  ...
# Zika virus vaccine                                              0.157377
# Zoster vaccine                                                  0.162295
# Vaccine                                                         1.000000
# NaN                                                             0.001639
# NaN                                                             0.001639
#
# [611 rows x 7 columns]

# %%
int(stats_nodes.loc['ACE inhibitor']['community'])
# Out:
# 1
