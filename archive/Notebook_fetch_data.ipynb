# %%
# Setup packages and file paths 
import requests
import pandas as pd
import time 

path = "/home/teijehidde/Documents/Git Blog and Coding/data_dump/"
data_file = "data_new6.json"

# %%
def downloadWikiNetwork(node_title, lang = "en"):
    api_endpoint = "https://" + lang + ".wikipedia.org/w/api.php" # fr.wikipedia.org; https://en.wikipedia.org
    wiki_data = []
    print("Starting download of network " + node_title + " in language " + lang + ".")
    
    # 1: download data on the node_title wikipage.
    S = requests.Session()
    params_node_title = {
        "action": "query",
        "titles": node_title,
        "prop": "info|links|langlinks", 
        "plnamespace": 0, 
        "pllimit": 500,
        "lllimit": 500, 
        "format": "json"
    }
    response = S.get(url=api_endpoint, params=params_node_title)
    wiki_data.append(response.json())
    
    while 'continue' in wiki_data[-1].keys():
        params_cont = params_node_title
        if 'plcontinue' in wiki_data[-1]['continue']:
            params_cont["plcontinue"] = wiki_data[-1]['continue']['plcontinue'] 
            print('plcontinue: ' + params_cont["plcontinue"])

        elif 'llcontinue' in wiki_data[-1]['continue']:
            params_cont["llcontinue"] = wiki_data[-1]['continue']['llcontinue'] 
            print('llcontinue: ' + params_cont["llcontinue"])

        response = S.get(url=api_endpoint, params=params_cont)
        wiki_data.append(response.json())

    # 2: download data on the links of node_title wikipage.
    S = requests.Session()
    params_network_title = {
        "action": "query",
        "generator": "links",
        "titles": node_title,
        "gplnamespace": 0, 
        "gpllimit": 500, 
        "prop": "info|links|langlinks", 
        "plnamespace": 0,
        "pllimit": 500,
        "lllang": "en", 
        "lllimit":500,
        "format": "json"
    }
    response = S.get(url=api_endpoint, params=params_network_title)
    wiki_data.append(response.json())

    while 'continue' in wiki_data[-1].keys():
        params_cont = params_network_title
        if 'plcontinue' in wiki_data[-1]['continue']:
            params_cont["plcontinue"] = wiki_data[-1]['continue']['plcontinue'] 
            print('plcontinue: ' + params_cont["plcontinue"])

        elif 'llcontinue' in wiki_data[-1]['continue']:
            params_cont["llcontinue"] = wiki_data[-1]['continue']['llcontinue'] 
            print('llcontinue: ' + params_cont["llcontinue"])

        elif 'gplcontinue' in wiki_data[-1]['continue']: 
            params_cont["gplcontinue"] = wiki_data[-1]['continue']['gplcontinue']
            print('gplcontinue: ' + params_cont["gplcontinue"])

        response = S.get(url=api_endpoint, params = params_cont)
        wiki_data.append(response.json())

    # 3: creating list of available nodes in wiki_data. 
    all_nodes = []

    for item in wiki_data:
        all_nodes = all_nodes + list(item['query']['pages'].keys())
    all_nodes = list(set(all_nodes))
    all_nodes = [int(i) for i in all_nodes if int(i) > 0]
    all_nodes = [str(i) for i in all_nodes]
    
    network_data_df = pd.DataFrame(
        columns = ['title', 'lang', 'pageid', 'uniqueid', 'lastrevid', 'links', 'langlinks', 'ego'], # complete list: ['ns', 'title', 'missing', 'contentmodel', 'pagelanguage', 'pagelanguagehtmlcode', 'pageid', 'lastrevid', 'length', 'links', 'langlinks']
        index = all_nodes)

    # 4: Using all_nodes to go through list of raw data from API. 
    for node in all_nodes:
        network_data_df.at[node,'links'] = []
        network_data_df.at[node,'langlinks'] = []
        for item in wiki_data:
            if node in item['query']['pages'].keys(): # possibility:  df_new_wiki_data.update(item) #, errors = 'raise') 
                network_data_df.at[node, 'title'] = item['query']['pages'][node]['title']
                network_data_df.at[node,'lang'] = item['query']['pages'][node]['pagelanguage']
                network_data_df.at[node,'pageid'] = item['query']['pages'][node]['pageid']
                network_data_df.at[node,'uniqueid'] = network_data_df.at[node,'lang'] + str(network_data_df.at[node,'pageid'])
                network_data_df.at[node,'lastrevid'] = item['query']['pages'][node]['lastrevid']
                if network_data_df.at[node,'title'] == node_title.replace('_', ' '): network_data_df.at[node,'ego'] = True

                if 'links' in item['query']['pages'][node].keys():
                    for link in item['query']['pages'][node]['links']:
                        network_data_df.at[node,'links'].append(link['title'])

                if 'langlinks' in item['query']['pages'][node].keys(): 
                    network_data_df.at[node,'langlinks'] = network_data_df.at[node,'langlinks'] + item['query']['pages'][node]['langlinks']

    # returns panda with all data from network. 
    return (network_data_df, wiki_data)

# %%
# Function B: Downloading multiple languages of one topic and saving them to json/panda file. 
def downloadMultiLangWikiNetwork(node_title, original_lang = 'en', additional_langs = ["ar", "ja", "es", "zh", "fr", "ru"]): # or: 'available_langs'
    network_data_df = downloadWikiNetwork(node_title=node_title, lang=original_lang)
    available_langs = network_data_df.loc[network_data_df['ego'] == True]['langlinks'].values.tolist()[0]

    if additional_langs == []:
        print('The wikipedia page is available in the following languages:')         
        print(available_langs)
    
    else:
        for item in available_langs: 
            if item['lang'] in additional_langs:
                network_data_df_additional = downloadWikiNetwork(node_title = item['*'], lang = item['lang'])
                network_data_df = pd.concat([network_data_df, network_data_df_additional], ignore_index=True, sort=False)
                
    try: 
        network_data_saved = pd.read_json((path + data_file), orient='split')
    except:
        network_data_saved = None
    network_data_df = pd.concat([network_data_df, network_data_saved], ignore_index=True, sort=False)
    network_data_df = network_data_df.loc[network_data_df.astype(str).drop_duplicates(subset=['title', 'lang', 'ego'], keep = 'first').index].reset_index(drop=True)
    network_data_df.to_json((path + data_file), orient='split')
    print("Download of network and additional languages finished. Returning to main menu...") 
    time.sleep(5)

# %%
wiki_network = downloadWikiNetwork('Gender_parity')
# Out:
# Starting download of network Gender_parity in language en.
# plcontinue: 358|0|Hassiba_Boulmerka
# plcontinue: 358|0|Sétif
# plcontinue: 3415|0|Glacial_landform
# plcontinue: 3415|0|Sport_in_Bulgaria
# plcontinue: 3462|0|Inter_Press_Service
# plcontinue: 5478|0|Azerbaijan
# plcontinue: 5478|0|Protestant
# plcontinue: 5488|0|Hippopotamus
# plcontinue: 5593|0|Australia_Group
# plcontinue: 5593|0|List_of_earthquakes_in_Cyprus
# plcontinue: 8620|0|Eko_Eko_Azarak
# plcontinue: 10577|0|Bilateral_trade
# plcontinue: 10577|0|Lactose_intolerant
# plcontinue: 10577|0|Tampere_University
# plcontinue: 10796|0|Postcolonial_feminism
# plcontinue: 11107|0|Quebec_City
# plcontinue: 11185|0|Domestic_violence
# plcontinue: 31717|0|Scottish_National_Party
# plcontinue: 31769|0|Geneva
# plcontinue: 31769|0|United_Nations_Interpretation_Service
# plcontinue: 31964|0|Nobel_Prize_in_Chemistry
# plcontinue: 33582|0|Mairead_Maguire
# plcontinue: 33583|0|Human_Resources_for_Health
# plcontinue: 33583|0|United_Nations_in_popular_culture
# plcontinue: 57744|0|African_Capacity_for_Immediate_Response_to_Crises
# plcontinue: 57744|0|PMID_(identifier)
# plcontinue: 58849|0|Feminist_views_on_prostitution
# plcontinue: 58849|0|Third_gender
# plcontinue: 76762|0|ISO_3166-2:CD
# plcontinue: 76762|0|Ubangi_River
# plcontinue: 83525|0|Misogyny
# plcontinue: 145439|0|Feminism_in_Malaysia
# plcontinue: 145439|0|Reproductive_coercion
# plcontinue: 147575|0|Charles_Kickham
# plcontinue: 147575|0|Last_Glacial_Period
# plcontinue: 147575|0|Uí_Liatháin
# plcontinue: 162025|0|Transgender_rights_movement
# plcontinue: 168717|0|Denial
# plcontinue: 168717|0|Racist_music
# plcontinue: 172185|0|Regional_Comprehensive_Economic_Corridor
# plcontinue: 175581|0|Feminism_in_Mali
# plcontinue: 175581|0|One-party_state
# plcontinue: 175581|0|Women_in_Ivory_Coast
# plcontinue: 177765|0|Gender_Empowerment_Measure
# plcontinue: 177765|0|University_of_Nebraska–Lincoln
# plcontinue: 200977|0|Promotional_models
# plcontinue: 222074|0|Feminist_literature
# plcontinue: 236331|0|Behavior
# plcontinue: 236331|0|Texas_State_University-San_Marcos
# plcontinue: 280746|0|Pchum_Ben
# plcontinue: 349303|0|Coordinated_Universal_Time
# plcontinue: 349303|0|Jubail
# plcontinue: 349303|0|South_Africa
# plcontinue: 350939|0|Districts_of_Yemen
# plcontinue: 350939|0|Shabwah_Governorate
# plcontinue: 353446|0|Donna_M._Hughes
# plcontinue: 353446|0|Lesbian_feminism
# plcontinue: 353446|0|Ursula_Mellor_Bright
# plcontinue: 355587|0|Labor_feminism
# plcontinue: 358999|0|Fourth-wave_feminism
# plcontinue: 399735|0|John_Maynard_Keynes
# plcontinue: 445022|0|Feminism_in_Sweden
# plcontinue: 469034|0|Feminism_in_Poland
# plcontinue: 469034|0|Sexually_transmitted_diseases
# plcontinue: 504356|0|Goddess_movement
# plcontinue: 512045|0|Men's_rights
# plcontinue: 539765|0|List_of_feminist_rhetoricians
# plcontinue: 573937|0|Fumiko_Hayashi_(author)
# plcontinue: 573937|0|Umbrella_Movement
# plcontinue: 631216|0|Christian_feminism
# plcontinue: 631216|0|Political_ideologies_in_the_United_States
# plcontinue: 632922|0|Gayle_Rubin
# plcontinue: 656951|0|International_Conference_on_Population_and_Development
# plcontinue: 748253|0|Feminist_theory
# plcontinue: 790968|0|Feminism_in_Nigeria
# plcontinue: 790968|0|Sexual_inversion_(sexology)
# plcontinue: 850705|0|Sikh_feminism
# plcontinue: 854811|0|Chantal_Chawaf
# plcontinue: 912961|0|Materialist_feminism
# plcontinue: 973368|0|List_of_feminist_rhetoricians
# plcontinue: 51463428|0|Christian_feminism
# plcontinue: 52077680|0|Feminist_geography
# plcontinue: 52374266|0|Kongreya_Star
# plcontinue: 54102442|0|Feminist_theory
# plcontinue: 54967685|0|Social_feminism
# plcontinue: 55300590|0|Shamsunnahar_Mahmud
# plcontinue: 56000450|0|Lean_startup
# plcontinue: 56297812|0|Lorena_Weeks
# plcontinue: 57494486|0|Mizrahi_feminism
# plcontinue: 58891529|0|Feminist_HCI
# plcontinue: 59935579|0|Misogyny
# plcontinue: 60436812|0|Reform_Act_1832
# plcontinue: 60911739|0|Feminist_metaphysics
# plcontinue: 61225321|0|Hong_Kong_1_July_marches
# plcontinue: 61428153|0|Women-only_space
# plcontinue: 62416988|0|Prison_Special
# plcontinue: 63635508|0|Maternal_feminism
# plcontinue: 65622835|0|Buddhist_feminism
# plcontinue: 66602499|0|Feminism_in_Nepal

# %%
wiki_network[1][0]
# Out:
# {'batchcomplete': '',
#  'query': {'normalized': [{'from': 'Gender_parity', 'to': 'Gender parity'}],
#   'pages': {'65331440': {'pageid': 65331440,
#     'ns': 0,
#     'title': 'Gender parity',
#     'contentmodel': 'wikitext',
#     'pagelanguage': 'en',
#     'pagelanguagehtmlcode': 'en',
#     'pagelanguagedir': 'ltr',
#     'touched': '2021-08-19T02:22:55Z',
#     'lastrevid': 1035826258,
#     'length': 25457,
#     'links': [{'ns': 0, 'title': "African-American women's suffrage movement"},
#      {'ns': 0, 'title': 'Africana womanism'},
#      {'ns': 0, 'title': 'Algeria'},
#      {'ns': 0, 'title': 'Analytical feminism'},
#      {'ns': 0, 'title': 'Anarcha-feminism'},
#      {'ns': 0, 'title': 'Anti-abortion feminism'},
#      {'ns': 0, 'title': 'Antifeminism'},
#      {'ns': 0, 'title': 'Asian feminist theology'},
#      {'ns': 0, 'title': 'Atheist feminism'},
#      {'ns': 0, 'title': 'Bicycling and feminism'},
#      {'ns': 0, 'title': 'Black feminism'},
#      {'ns': 0, 'title': 'Bolivia'},
#      {'ns': 0, 'title': 'Buddhist feminism'},
#      {'ns': 0, 'title': 'Bulgaria'},
#      {'ns': 0, 'title': 'Canada'},
#      {'ns': 0, 'title': 'Carceral feminism'},
#      {'ns': 0, 'title': 'Care work'},
#      {'ns': 0, 'title': 'Central African Republic'},
#      {'ns': 0, 'title': 'Chad'},
#      {'ns': 0, 'title': 'Chicana feminism'},
#      {'ns': 0, 'title': 'Christian feminism'},
#      {'ns': 0, 'title': 'Criticism of marriage'},
#      {'ns': 0, 'title': 'Cultural feminism'},
#      {'ns': 0, 'title': 'Cyberfeminism'},
#      {'ns': 0, 'title': 'Cyprus'},
#      {'ns': 0, 'title': 'Darfur'},
#      {'ns': 0, 'title': 'Democratic Republic of the Congo'},
#      {'ns': 0, 'title': 'Dianic Wicca'},
#      {'ns': 0, 'title': 'Difference feminism'},
#      {'ns': 0, 'title': 'Doi (identifier)'},
#      {'ns': 0, 'title': 'Ecofeminism'},
#      {'ns': 0, 'title': 'Egypt'},
#      {'ns': 0, 'title': 'Embedded feminism'},
#      {'ns': 0, 'title': 'Equality feminism'},
#      {'ns': 0, 'title': 'Equity feminism'},
#      {'ns': 0, 'title': 'Eugenic feminism'},
#      {'ns': 0, 'title': 'Fat feminism'},
#      {'ns': 0, 'title': 'Female education'},
#      {'ns': 0, 'title': 'Female genital mutilation'},
#      {'ns': 0, 'title': 'Femicide'},
#      {'ns': 0, 'title': 'Feminism'},
#      {'ns': 0, 'title': 'Feminism (international relations)'},
#      {'ns': 0, 'title': 'Feminism and equality'},
#      {'ns': 0, 'title': 'Feminism and media'},
#      {'ns': 0, 'title': 'Feminism and modern architecture'},
#      {'ns': 0, 'title': 'Feminism in Albania'},
#      {'ns': 0, 'title': 'Feminism in Argentina'},
#      {'ns': 0, 'title': 'Feminism in Australia'},
#      {'ns': 0, 'title': 'Feminism in Bangladesh'},
#      {'ns': 0, 'title': 'Feminism in Brazil'},
#      {'ns': 0, 'title': 'Feminism in Canada'},
#      {'ns': 0, 'title': 'Feminism in Chile'},
#      {'ns': 0, 'title': 'Feminism in China'},
#      {'ns': 0, 'title': 'Feminism in Egypt'},
#      {'ns': 0, 'title': 'Feminism in Ethiopia'},
#      {'ns': 0, 'title': 'Feminism in Finland'},
#      {'ns': 0, 'title': 'Feminism in France'},
#      {'ns': 0, 'title': 'Feminism in Germany'},
#      {'ns': 0, 'title': 'Feminism in Ghana'},
#      {'ns': 0, 'title': 'Feminism in Greece'},
#      {'ns': 0, 'title': 'Feminism in Haiti'},
#      {'ns': 0, 'title': 'Feminism in Honduras'},
#      {'ns': 0, 'title': 'Feminism in Hong Kong'},
#      {'ns': 0, 'title': 'Feminism in India'},
#      {'ns': 0, 'title': 'Feminism in Indonesia'},
#      {'ns': 0, 'title': 'Feminism in Iran'},
#      {'ns': 0, 'title': 'Feminism in Iraq'},
#      {'ns': 0, 'title': 'Feminism in Israel'},
#      {'ns': 0, 'title': 'Feminism in Italy'},
#      {'ns': 0, 'title': 'Feminism in Japan'},
#      {'ns': 0, 'title': 'Feminism in Latin America'},
#      {'ns': 0, 'title': 'Feminism in Malaysia'},
#      {'ns': 0, 'title': 'Feminism in Mali'},
#      {'ns': 0, 'title': 'Feminism in Mexico'},
#      {'ns': 0, 'title': 'Feminism in Nepal'},
#      {'ns': 0, 'title': 'Feminism in New Zealand'},
#      {'ns': 0, 'title': 'Feminism in Nigeria'},
#      {'ns': 0, 'title': 'Feminism in Northern Cyprus'},
#      {'ns': 0, 'title': 'Feminism in Norway'},
#      {'ns': 0, 'title': 'Feminism in Pakistan'},
#      {'ns': 0, 'title': 'Feminism in Paraguay'},
#      {'ns': 0, 'title': 'Feminism in Poland'},
#      {'ns': 0, 'title': 'Feminism in Russia'},
#      {'ns': 0, 'title': 'Feminism in Saudi Arabia'},
#      {'ns': 0, 'title': 'Feminism in South Africa'},
#      {'ns': 0, 'title': 'Feminism in South Korea'},
#      {'ns': 0, 'title': 'Feminism in Sweden'},
#      {'ns': 0, 'title': 'Feminism in Taiwan'},
#      {'ns': 0, 'title': 'Feminism in Thailand'},
#      {'ns': 0, 'title': 'Feminism in Turkey'},
#      {'ns': 0, 'title': 'Feminism in United Kingdom'},
#      {'ns': 0, 'title': 'Feminism in culture'},
#      {'ns': 0, 'title': 'Feminism in international relations'},
#      {'ns': 0, 'title': 'Feminism in the Democratic Republic of the Congo'},
#      {'ns': 0, 'title': 'Feminism in the Netherlands'},
#      {'ns': 0, 'title': 'Feminism in the Philippines'},
#      {'ns': 0, 'title': 'Feminism in the Republic of Ireland'},
#      {'ns': 0, 'title': 'Feminism in the United Kingdom'},
#      {'ns': 0, 'title': 'Feminism in the United States'},
#      {'ns': 0, 'title': 'Feminist HCI'},
#      {'ns': 0, 'title': 'Feminist activism in hip hop'},
#      {'ns': 0, 'title': 'Feminist aesthetics'},
#      {'ns': 0, 'title': 'Feminist anthropology'},
#      {'ns': 0, 'title': 'Feminist archaeology'},
#      {'ns': 0, 'title': 'Feminist art'},
#      {'ns': 0, 'title': 'Feminist art criticism'},
#      {'ns': 0, 'title': 'Feminist art movement'},
#      {'ns': 0, 'title': 'Feminist biology'},
#      {'ns': 0, 'title': 'Feminist businesses'},
#      {'ns': 0, 'title': "Feminist children's literature"},
#      {'ns': 0, 'title': 'Feminist constructivism'},
#      {'ns': 0, 'title': 'Feminist economics'},
#      {'ns': 0, 'title': 'Feminist effects on society'},
#      {'ns': 0, 'title': 'Feminist empiricism'},
#      {'ns': 0, 'title': 'Feminist epistemology'},
#      {'ns': 0, 'title': 'Feminist ethics'},
#      {'ns': 0, 'title': 'Feminist existentialism'},
#      {'ns': 0, 'title': 'Feminist film theory'},
#      {'ns': 0, 'title': 'Feminist geography'},
#      {'ns': 0, 'title': 'Feminist history'},
#      {'ns': 0, 'title': 'Feminist justice ethics'},
#      {'ns': 0, 'title': 'Feminist language reform'},
#      {'ns': 0, 'title': 'Feminist legal theory'},
#      {'ns': 0, 'title': 'Feminist literary criticism'},
#      {'ns': 0, 'title': 'Feminist literature'},
#      {'ns': 0, 'title': 'Feminist metaphysics'},
#      {'ns': 0, 'title': 'Feminist method'},
#      {'ns': 0, 'title': 'Feminist movement'},
#      {'ns': 0, 'title': 'Feminist movements and ideologies'},
#      {'ns': 0, 'title': 'Feminist pathways perspective'},
#      {'ns': 0, 'title': 'Feminist pedagogy'},
#      {'ns': 0, 'title': 'Feminist philosophy'},
#      {'ns': 0, 'title': 'Feminist philosophy of science'},
#      {'ns': 0, 'title': 'Feminist political ecology'},
#      {'ns': 0, 'title': 'Feminist political theory'},
#      {'ns': 0, 'title': 'Feminist pornography'},
#      {'ns': 0, 'title': 'Feminist post-structuralist discourse analysis'},
#      {'ns': 0, 'title': 'Feminist psychology'},
#      {'ns': 0, 'title': 'Feminist revisionist mythology'},
#      {'ns': 0, 'title': 'Feminist rhetoric'},
#      {'ns': 0, 'title': 'Feminist school of criminology'},
#      {'ns': 0, 'title': 'Feminist science fiction'},
#      {'ns': 0, 'title': 'Feminist separatism'},
#      {'ns': 0, 'title': 'Feminist sex wars'},
#      {'ns': 0, 'title': 'Feminist sexology'},
#      {'ns': 0, 'title': 'Feminist sociology'},
#      {'ns': 0, 'title': 'Feminist stripper'},
#      {'ns': 0, 'title': 'Feminist technoscience'},
#      {'ns': 0, 'title': 'Feminist theology'},
#      {'ns': 0, 'title': 'Feminist theory'},
#      {'ns': 0, 'title': 'Feminist theory in composition studies'},
#      {'ns': 0, 'title': 'Feminist views on BDSM'},
#      {'ns': 0, 'title': 'Feminist views on pornography'},
#      {'ns': 0, 'title': 'Feminist views on prostitution'},
#      {'ns': 0, 'title': 'Feminist views on sexual orientation'},
#      {'ns': 0, 'title': 'Feminist views on sexuality'},
#      {'ns': 0, 'title': 'Feminist views on the Oedipus complex'},
#      {'ns': 0, 'title': 'Feminist views on transgender topics'},
#      {'ns': 0, 'title': 'Finland'},
#      {'ns': 0, 'title': 'First-wave feminism'},
#      {'ns': 0, 'title': 'Food and Agriculture Organization'},
#      {'ns': 0, 'title': 'Fourth-wave feminism'},
#      {'ns': 0, 'title': 'France'},
#      {'ns': 0, 'title': 'French feminist theory'},
#      {'ns': 0, 'title': 'French post-structuralist feminism'},
#      {'ns': 0, 'title': 'Gender Development Index'},
#      {'ns': 0, 'title': 'Gender Parity Index'},
#      {'ns': 0, 'title': 'Gender disparities in health'},
#      {'ns': 0, 'title': 'Gender diversity'},
#      {'ns': 0, 'title': 'Gender equality'},
#      {'ns': 0, 'title': 'Gender identity'},
#      {'ns': 0, 'title': 'Gender inequality'},
#      {'ns': 0, 'title': 'Gender mainstreaming'},
#      {'ns': 0, 'title': 'Gender pay gap'},
#      {'ns': 0, 'title': 'Gender studies'},
#      {'ns': 0, 'title': 'Germany'},
#      {'ns': 0, 'title': 'Gila Hanna'},
#      {'ns': 0, 'title': 'Girl power'},
#      {'ns': 0, 'title': 'Global Gender Gap Index'},
#      {'ns': 0, 'title': 'Global Gender Gap Report'},
#      {'ns': 0, 'title': 'Global feminism'},
#      {'ns': 0, 'title': 'Goddess movement'},
#      {'ns': 0, 'title': 'Golan Heights'},
#      {'ns': 0, 'title': 'Gynocentrism'},
#      {'ns': 0, 'title': 'Gypsy feminism'},
#      {'ns': 0, 'title': 'Haiti'},
#      {'ns': 0, 'title': 'Hindu feminism'},
#      {'ns': 0, 'title': 'Hip-hop feminism'},
#      {'ns': 0, 'title': 'History of German women'},
#      {'ns': 0, 'title': 'History of feminism'},
#      {'ns': 0, 'title': 'History of women in Canada'},
#      {'ns': 0, 'title': 'History of women in the United Kingdom'},
#      {'ns': 0, 'title': 'History of women in the United States'},
#      {'ns': 0, 'title': 'Honor killing'},
#      {'ns': 0, 'title': 'Human sex ratio'},
#      {'ns': 0, 'title': 'ISBN (identifier)'},
#      {'ns': 0, 'title': 'ISSN (identifier)'},
#      {'ns': 0, 'title': 'Iceland'},
#      {'ns': 0, 'title': 'Index of feminism articles'},
#      {'ns': 0, 'title': 'Indigenous feminism'},
#      {'ns': 0, 'title': 'Individualist feminism'},
#      {'ns': 0, 'title': 'International Day of the Girl Child'},
#      {'ns': 0, 'title': 'International Labour Organization'},
#      {'ns': 0, 'title': "International Women's Day"},
#      {'ns': 0, 'title': 'Iran'},
#      {'ns': 0, 'title': 'Ireland'},
#      {'ns': 0, 'title': 'Islamic feminism'},
#      {'ns': 0, 'title': 'Ivory Coast'},
#      {'ns': 0, 'title': 'Jewish feminism'},
#      {'ns': 0, 'title': 'Jineology'},
#      {'ns': 0, 'title': 'Jordan'},
#      {'ns': 0, 'title': 'Kuwait'},
#      {'ns': 0, 'title': 'Kyriarchy'},
#      {'ns': 0, 'title': 'Labor feminism'},
#      {'ns': 0, 'title': 'Latvia'},
#      {'ns': 0, 'title': 'Lebanon'},
#      {'ns': 0, 'title': 'Lesbian feminism'},
#      {'ns': 0, 'title': 'Lesbian separatism'},
#      {'ns': 0, 'title': 'Liberal feminism'},
#      {'ns': 0, 'title': 'Liberia'},
#      {'ns': 0, 'title': 'Lipstick feminism'},
#      {'ns': 0, 'title': 'List of American feminist literature'},
#      {'ns': 0, 'title': 'List of Jewish feminists'},
#      {'ns': 0, 'title': 'List of Muslim feminists'},
#      {'ns': 0, 'title': 'List of conservative feminisms'},
#      {'ns': 0, 'title': 'List of ecofeminist authors'},
#      {'ns': 0, 'title': 'List of feminist art critics'},
#      {'ns': 0, 'title': 'List of feminist comic books'},
#      {'ns': 0, 'title': 'List of feminist economists'},
#      {'ns': 0, 'title': 'List of feminist literature'},
#      {'ns': 0, 'title': 'List of feminist parties'},
#      {'ns': 0, 'title': 'List of feminist philosophers'},
#      {'ns': 0, 'title': 'List of feminist poets'},
#      {'ns': 0, 'title': 'List of feminist rhetoricians'},
#      {'ns': 0, 'title': 'List of feminists'},
#      {'ns': 0, 'title': 'List of suffragists and suffragettes'},
#      {'ns': 0, 'title': "List of women's rights activists"},
#      {'ns': 0, 'title': "List of women's studies journals"},
#      {'ns': 0, 'title': 'Male gaze'},
#      {'ns': 0, 'title': 'Mali'},
#      {'ns': 0, 'title': 'Marxist feminism'},
#      {'ns': 0, 'title': 'Materialist feminism'},
#      {'ns': 0, 'title': 'Maternal feminism'},
#      {'ns': 0, 'title': 'Matriarchal religion'},
#      {'ns': 0, 'title': 'Matriarchy'},
#      {'ns': 0, 'title': 'Matriarchy in feminist thought'},
#      {'ns': 0, 'title': 'Mauritania'},
#      {'ns': 0, 'title': 'Measures of gender equality'},
#      {'ns': 0, 'title': "Men's studies"},
#      {'ns': 0, 'title': 'Men in feminism'},
#      {'ns': 0, 'title': 'Misogyny'},
#      {'ns': 0, 'title': 'Mizrahi feminism'},
#      {'ns': 0, 'title': 'Mormon feminism'},
#      {'ns': 0, 'title': 'Morocco'},
#      {'ns': 0, 'title': 'Namibia'},
#      {'ns': 0, 'title': 'Native American feminism'},
#      {'ns': 0, 'title': 'Neofeminism'},
#      {'ns': 0, 'title': 'Networked feminism'},
#      {'ns': 0, 'title': 'New Zealand'},
#      {'ns': 0, 'title': 'New feminism'},
#      {'ns': 0, 'title': 'Nicaragua'},
#      {'ns': 0, 'title': 'Norway'},
#      {'ns': 0, 'title': 'OCLC (identifier)'},
#      {'ns': 0, 'title': 'OECD'},
#      {'ns': 0, 'title': 'Orthodox Jewish feminism'},
#      {'ns': 0, 'title': 'PMC (identifier)'},
#      {'ns': 0, 'title': 'PMID (identifier)'},
#      {'ns': 0, 'title': 'Pakistan'},
#      {'ns': 0, 'title': 'Patriarchy'},
#      {'ns': 0, 'title': 'Philippines'},
#      {'ns': 0, 'title': 'Political lesbianism'},
#      {'ns': 0, 'title': 'Post-structural feminism'},
#      {'ns': 0, 'title': 'Postcolonial feminism'},
#      {'ns': 0, 'title': 'Postfeminism'},
#      {'ns': 0, 'title': 'Postmodern feminism'},
#      {'ns': 0, 'title': 'Pro-feminism'},
#      {'ns': 0, 'title': 'Protofeminism'},
#      {'ns': 0, 'title': 'Purplewashing'},
#      {'ns': 0, 'title': 'Qatar'},
#      {'ns': 0, 'title': 'Radical feminism'},
#      {'ns': 0, 'title': 'Radical lesbianism'},
#      {'ns': 0, 'title': 'Reclaiming (Neopaganism)'},
#      {'ns': 0, 'title': 'Religious feminism'},
#      {'ns': 0, 'title': 'Reproductive justice'},
#      {'ns': 0, 'title': 'Rwanda'},
#      {'ns': 0, 'title': 'Saudi Arabia'},
#      {'ns': 0, 'title': 'Second-generation gender bias'},
#      {'ns': 0, 'title': 'Second-wave feminism'},
#      {'ns': 0, 'title': 'Seriality (gender studies)'},
#      {'ns': 0, 'title': 'Sex-positive feminism'},
#      {'ns': 0, 'title': 'Sex differences in humans'},
#      {'ns': 0, 'title': "Sex workers' rights"},
#      {'ns': 0, 'title': 'Sexual harassment'},
#      {'ns': 0, 'title': 'Sexual objectification'},
#      {'ns': 0, 'title': 'Sikh feminism'},
#      {'ns': 0, 'title': 'Slovakia'},
#      {'ns': 0, 'title': 'Social feminism'},
#      {'ns': 0, 'title': 'Social housekeeping'},
#      {'ns': 0, 'title': 'Socialist feminism'},
#      {'ns': 0, 'title': 'Somalia'},
#      {'ns': 0, 'title': 'South Sudan'},
#      {'ns': 0, 'title': 'Standpoint feminism'},
#      {'ns': 0, 'title': 'State feminism'},
#      {'ns': 0, 'title': 'Strategy on Gender Parity'},
#      {'ns': 0, 'title': 'Straw feminism'},
#      {'ns': 0, 'title': 'Sudan'},
#      {'ns': 0, 'title': 'Sweden'},
#      {'ns': 0, 'title': 'Syria'},
#      {'ns': 0, 'title': 'Thealogy'},
#      {'ns': 0, 'title': 'Third-wave feminism'},
#      {'ns': 0, 'title': 'Timeline of feminism'},
#      {'ns': 0,
#       'title': "Timeline of first women's suffrage in majority-Muslim countries"},
#      {'ns': 0, 'title': 'Timeline of second-wave feminism'},
#      {'ns': 0,
#       'title': "Timeline of women's legal rights (other than voting)"},
#      {'ns': 0, 'title': "Timeline of women's suffrage"},
#      {'ns': 0, 'title': "Timeline of women's suffrage in the United States"},
#      {'ns': 0, 'title': 'Toxic masculinity'},
#      {'ns': 0, 'title': 'Transfeminism'},
#      {'ns': 0, 'title': 'Transnational feminism'},
#      {'ns': 0, 'title': 'Triple oppression'},
#      {'ns': 0, 'title': 'Turkey'},
#      {'ns': 0, 'title': 'UNESCO'},
#      {'ns': 0, 'title': 'UNICEF'},
#      {'ns': 0, 'title': 'UN Women'},
#      {'ns': 0, 'title': 'United Kingdom'},
#      {'ns': 0, 'title': 'United Nations'},
#      {'ns': 0, 'title': 'United Nations Department of Peace Operations'},
#      {'ns': 0, 'title': 'United Nations High Commissioner for Refugees'},
#      {'ns': 0, 'title': 'United Nations Secretariat'},
#      {'ns': 0, 'title': 'Unpaid work'},
#      {'ns': 0, 'title': 'Vegetarian ecofeminism'},
#      {'ns': 0, 'title': 'Victim feminism'},
#      {'ns': 0, 'title': 'Violence against women'},
#      {'ns': 0, 'title': 'War on women'},
#      {'ns': 0, 'title': 'White feminism'},
#      {'ns': 0, 'title': 'Womanism'},
#      {'ns': 0, 'title': 'Womanist theology'},
#      {'ns': 0, 'title': "Women's health"},
#      {'ns': 0, 'title': "Women's history"},
#      {'ns': 0, 'title': "Women's rights"},
#      {'ns': 0, 'title': "Women's studies"},
#      {'ns': 0, 'title': "Women's suffrage"},
#      {'ns': 0, 'title': "Women's suffrage in Australia"},
#      {'ns': 0, 'title': "Women's suffrage in Austria"},
#      {'ns': 0, 'title': "Women's suffrage in Canada"},
#      {'ns': 0,
#       'title': "Women's suffrage in Francoist Spain and the democratic transition"},
#      {'ns': 0, 'title': "Women's suffrage in India"},
#      {'ns': 0, 'title': "Women's suffrage in Japan"},
#      {'ns': 0, 'title': "Women's suffrage in Kuwait"},
#      {'ns': 0, 'title': "Women's suffrage in Liechtenstein"},
#      {'ns': 0, 'title': "Women's suffrage in New Zealand"},
#      {'ns': 0, 'title': "Women's suffrage in Sweden"},
#      {'ns': 0, 'title': "Women's suffrage in Switzerland"},
#      {'ns': 0, 'title': "Women's suffrage in Utah"},
#      {'ns': 0, 'title': "Women's suffrage in Virginia"},
#      {'ns': 0, 'title': "Women's suffrage in Wales"},
#      {'ns': 0, 'title': "Women's suffrage in Wyoming"},
#      {'ns': 0, 'title': "Women's suffrage in states of the United States"},
#      {'ns': 0, 'title': "Women's suffrage in the Cayman Islands"},
#      {'ns': 0, 'title': "Women's suffrage in the Spanish Civil War period"},
#      {'ns': 0, 'title': "Women's suffrage in the United Kingdom"},
#      {'ns': 0, 'title': "Women's suffrage in the United States"},
#      {'ns': 0, 'title': "Women's suffrage organizations"},
#      {'ns': 0, 'title': 'Women-only space'},
#      {'ns': 0, 'title': 'Women in Denmark'},
#      {'ns': 0, 'title': 'Women in Lebanon'},
#      {'ns': 0, 'title': 'Women in STEM fields'},
#      {'ns': 0, 'title': 'Women in Syria'},
#      {'ns': 0, 'title': 'Women in Trinidad and Tobago'},
#      {'ns': 0, 'title': 'Women in Ukraine'},
#      {'ns': 0, 'title': 'Women in Vietnam'},
#      {'ns': 0, 'title': 'Women in the workforce'},
#      {'ns': 0, 'title': 'World Economic Forum'},
#      {'ns': 0, 'title': 'World Food Programme'},
#      {'ns': 0, 'title': 'World Health Organization'},
#      {'ns': 0, 'title': 'Yemen'},
#      {'ns': 0, 'title': 'Écriture féminine'}],
#     'langlinks': [{'lang': 'ar', '*': 'التكافؤ بين الجنسين'},
#      {'lang': 'ca', '*': 'Paritat'},
#      {'lang': 'es', '*': 'Paridad de género'}]}}}}

# %%
wiki_network_df = wiki_network[0]

wiki_network_df.loc[wiki_network_df['title'] == 'Gender parity']
# Out:
#                   title lang    pageid    uniqueid   lastrevid  \
# 65331440  Gender parity   en  65331440  en65331440  1035826258
#
#                                                       links  \
# 65331440  [African-American women's suffrage movement, A...
#
#                                                   langlinks  ego
# 65331440  [{'lang': 'ar', '*': 'التكافؤ بين الجنسين'}, {...  NaN

# %%
network_data_df
# Out:
#                   title lang    pageid    uniqueid   lastrevid  \
# 0               Cgroups   en  28942492  en28942492  1032278529
# 1          Linux kernel   en  21347315  en21347315  1037151397
# 2                PearPC   en    656612    en656612  1019446604
# 3            Containerd   en  64656490  en64656490   972183911
# 4                GLinux   en  56356171  en56356171  1035653157
# ..                  ...  ...       ...         ...         ...
# 582  Solaris Containers   zh   4242669   zh4242669    63145567
# 583              软件版本周期   zh   1048013   zh1048013    10039555
# 584           Apache许可证   zh    740492    zh740492    64115378
# 585         Docker (軟體)   zh   6322282   zh6322282    58844869
# 586                 运行时   zh   1526715   zh1526715    15799050
#
#                                                  links  \
# 0    [Adaptive Domain Environment for Operating Sys...
# 1    [/sys, 0 A.D. (video game), 64-bit, AArch64, A...
# 2    [3Com, 64-bit, Adaptive Domain Environment for...
# 3                  [Cloud Native Computing Foundation]
# 4    [/e/ (operating system), 4MLinux, ALT Linux, A...
# ..                                                 ...
# 582  [Chroot, OpenSolaris, SPARC, Solaris 10, Solar...
# 583                                           [軟件版本週期]
# 584  [AROS Research Operating System, Abdera, Accum...
# 585                                           [Docker]
# 586                                              [執行期]
#
#                                              langlinks  ego
# 0                                                   []  NaN
# 1                                                   []  NaN
# 2                                                   []  NaN
# 3                                                   []  NaN
# 4                                                   []  NaN
# ..                                                 ...  ...
# 582  [{'lang': 'en', '*': 'Solaris Containers'}, {'...  NaN
# 583                                                 []  NaN
# 584  [{'lang': 'en', '*': 'Apache License'}, {'lang...  NaN
# 585                                                 []  NaN
# 586                                                 []  NaN
#
# [587 rows x 8 columns]

# %%
selected_network = 'Kubernetes'
page_langs = pd.DataFrame(network_data_df.loc[network_data_df['ego'] == True].loc[network_data_df['lang'] == 'en'].loc[network_data_df['title'] == selected_network]['langlinks'].iloc[0]).rename(columns={'*': 'title'})
saved_langs = network_data_df.loc[network_data_df['ego'] == True][['lang', 'title']]
options_langs =  pd.merge(saved_langs, page_langs, how ='inner', on =['lang', 'title'])

language_options = ["{}: {}".format(list(a.values())[0], list(a.values())[1]) for a in options_langs]
[{'label': a, 'value': a} for a in language_options]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-10bbb043ef22> in <module>
#       4 options_langs =  pd.merge(saved_langs, page_langs, how ='inner', on =['lang', 'title'])
#       5
# ----> 6 language_options = ["{}: {}".format(list(a.values())[0], list(a.values())[1]) for a in options_langs]
#       7 [{'label': a, 'value': a} for a in language_options]
#
# <ipython-input-111-10bbb043ef22> in <listcomp>(.0)
#       4 options_langs =  pd.merge(saved_langs, page_langs, how ='inner', on =['lang', 'title'])
#       5
# ----> 6 language_options = ["{}: {}".format(list(a.values())[0], list(a.values())[1]) for a in options_langs]
#       7 [{'label': a, 'value': a} for a in language_options]
#
# AttributeError: 'str' object has no attribute 'values'

# %%
input_var = 'teenNick'
input_var[0].upper() + input_var[1:]
# Out:
# 'TeenNick'

# %%
options_langs
# Out:
#   lang       title
# 0   ar  كوبيرنيتيس
# 1   es  Kubernetes
# 2   fr  Kubernetes
# 3   ja  Kubernetes
# 4   ru  Kubernetes
# 5   zh  Kubernetes

# %%
options_lang = pd.merge(saved_langs, page_langs, how ='inner', on =['lang', 'title']).to_dict('records')

# %%
options_lang + ['lang': lang, title: ]
# Out:
# [{'lang': 'ar', 'title': 'كوبيرنيتيس'},
#  {'lang': 'es', 'title': 'Kubernetes'},
#  {'lang': 'fr', 'title': 'Kubernetes'},
#  {'lang': 'ja', 'title': 'Kubernetes'},
#  {'lang': 'ru', 'title': 'Kubernetes'},
#  {'lang': 'zh', 'title': 'Kubernetes'}]

# %%
language_options = ["{}: {}".format(list(a.values())[0], list(a.values())[1]) for a in options_lang]

# %%
[{'label': a, 'value': a} for a in language_options]
# Out:
# [{'label': 'ar: كوبيرنيتيس', 'value': 'ar: كوبيرنيتيس'},
#  {'label': 'es: Kubernetes', 'value': 'es: Kubernetes'},
#  {'label': 'fr: Kubernetes', 'value': 'fr: Kubernetes'},
#  {'label': 'ja: Kubernetes', 'value': 'ja: Kubernetes'},
#  {'label': 'ru: Kubernetes', 'value': 'ru: Kubernetes'},
#  {'label': 'zh: Kubernetes', 'value': 'zh: Kubernetes'}]

# %%
# Kubernetes, Vaccine, Oxford, [Verkhovna_Rada this one seems to have a bug - fix later; see also 'Consumer_protection'] 
# wiki_data_kubs = downloadWikiNetwork('Kubernetes')
# wiki_data_Verkhovna_Rada = downloadWikiNetwork('Verkhovna_Rada')

# %%
network_data_df.loc[network_data_df['ego'] == True].loc[network_data_df['lang'] == 'en']['title'].values.tolist()
# Out:
# ['Kubernetes', 'Kubernetes', 'Snowmelt', 'Terrorism', 'Secularism', 'Vaccine']

# %%
# all_nodes

# %%
for item in wiki_data['query']['pages']: 
    if '2646623' in item['query']['pages'].keys():
       if 'links' in item['query']['pages']['2646623'].keys(): 
           print(item)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-b5c4b6475aa4> in <module>
# ----> 1 for item in wiki_data['query']['pages']:
#       2     if '2646623' in item['query']['pages'].keys():
#       3        if 'links' in item['query']['pages']['2646623'].keys():
#       4            print(item)
#
# TypeError: list indices must be integers or slices, not str
